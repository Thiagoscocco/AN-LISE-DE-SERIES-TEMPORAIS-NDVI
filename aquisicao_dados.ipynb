# %%
import ee

GEE_PROJECT_ID = "ndvi-estudos"

ee.Authenticate()
ee.Initialize(project=GEE_PROJECT_ID)
print("Google Earth Engine conectado com sucesso!")

# %%
# %run analise_mensal_ndvi.py

# %%
# %run analise_das_ndvi.py

# %%
# %run dados_climaticos_das.py

# %%
SCRIPT_CSV = "compilar_csv_modelagem.py"
OUTPUT_CSV_DIR = "outputs_csv"
OUTPUT_CSV_FILENAME = "dados_modelagem_ndvi.csv"

SAFRAS_PADRONIZADAS = [
    {"safra": "2018-2019", "inicio": "2018-11-15", "fim": "2019-04-01"},
    {"safra": "2019-2020", "inicio": "2019-11-12", "fim": "2020-04-05"},
    {"safra": "2021-2022", "inicio": "2021-11-10", "fim": "2022-04-15"},
    {"safra": "2022-2023", "inicio": "2022-11-01", "fim": "2023-04-04"},
    {"safra": "2023-2024", "inicio": "2023-11-14", "fim": "2024-04-02"},
    {"safra": "2025-2026", "inicio": "2025-11-11", "fim": "2026-04-10"},
]

get_ipython().run_line_magic("run", f"-i {SCRIPT_CSV}")
# Out:
# /home/thiago/Desktop/Projeto NDVI/Estudo Talhões/Scripts de Análise/estudos_analise_soja/.venv/lib/python3.10/site-packages/google/api_core/_python_version_support.py:254: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /home/thiago/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_000 | progresso 1.6% | valor=0.1990
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_015 | progresso 3.2% | valor=0.2618
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_030 | progresso 4.8% | valor=0.6151
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_045 | progresso 6.3% | valor=0.9265
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_060 | progresso 7.9% | valor=0.9318
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_075 | progresso 9.5% | valor=0.9279
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_090 | progresso 11.1% | valor=0.9083
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_105 | progresso 12.7% | valor=0.7596
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_120 | progresso 14.3% | valor=0.2988
# [CSV-MODELAGEM] NDVI 2018-2019 | DAS_135 | progresso 15.9% | valor=0.2988
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_000 | progresso 17.5% | valor=0.1816
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_015 | progresso 19.0% | valor=0.1933
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_030 | progresso 20.6% | valor=0.4415
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_045 | progresso 22.2% | valor=0.7226
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_060 | progresso 23.8% | valor=0.8536
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_075 | progresso 25.4% | valor=0.9240
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_090 | progresso 27.0% | valor=0.9083
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_105 | progresso 28.6% | valor=0.8966
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_120 | progresso 30.2% | valor=0.4278
# [CSV-MODELAGEM] NDVI 2019-2020 | DAS_135 | progresso 31.7% | valor=0.3339
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_000 | progresso 33.3% | valor=0.1738
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_015 | progresso 34.9% | valor=0.2050
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_030 | progresso 36.5% | valor=0.4472
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_045 | progresso 38.1% | valor=0.4355
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_060 | progresso 39.7% | valor=0.7167
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_075 | progresso 41.3% | valor=0.7949
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_090 | progresso 42.9% | valor=0.8731
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_105 | progresso 44.4% | valor=0.8731
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_120 | progresso 46.0% | valor=0.6824
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_135 | progresso 47.6% | valor=0.5528
# [CSV-MODELAGEM] NDVI 2021-2022 | DAS_150 | progresso 49.2% | valor=0.4785
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_000 | progresso 50.8% | valor=0.1699
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_015 | progresso 52.4% | valor=0.2010
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_030 | progresso 54.0% | valor=0.6660
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_045 | progresso 55.6% | valor=0.8185
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_060 | progresso 57.1% | valor=0.8068
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_075 | progresso 58.7% | valor=0.7998
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_090 | progresso 60.3% | valor=0.7403
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_105 | progresso 61.9% | valor=0.6152
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_120 | progresso 63.5% | valor=0.3693
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_135 | progresso 65.1% | valor=0.2676
# [CSV-MODELAGEM] NDVI 2022-2023 | DAS_150 | progresso 66.7% | valor=0.2363
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_000 | progresso 68.3% | valor=0.2168
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_015 | progresso 69.8% | valor=0.2168
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_030 | progresso 71.4% | valor=0.6425
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_045 | progresso 73.0% | valor=0.8222
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_060 | progresso 74.6% | valor=0.6153
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_075 | progresso 76.2% | valor=0.9163
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_090 | progresso 77.8% | valor=0.9209
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_105 | progresso 79.4% | valor=0.8457
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_120 | progresso 81.0% | valor=0.3067
# [CSV-MODELAGEM] NDVI 2023-2024 | DAS_135 | progresso 82.5% | valor=0.2637
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_000 | progresso 84.1% | valor=0.1777
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_015 | progresso 85.7% | valor=0.2481
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_030 | progresso 87.3% | valor=0.7091
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_045 | progresso 88.9% | valor=0.9161
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_060 | progresso 90.5% | valor=0.9237
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_075 | progresso 92.1% | valor=0.9397
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_090 | progresso 93.7% | valor=0.8887
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_105 | progresso 95.2% | valor=0.8193
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_120 | progresso 96.8% | valor=0.7324
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_135 | progresso 98.4% | valor=0.2245
# [CSV-MODELAGEM] NDVI 2025-2026 | DAS_150 | progresso 100.0% | valor=0.2245
# [CLIMA-DAS] Consultando NASA POWER de 2018-11-15 ate 2026-04-10 para lat=-28.179388, lon=-52.392167
# [CSV-MODELAGEM] 100.0% concluido. CSV consolidado salvo em 'outputs_csv/dados_modelagem_ndvi.csv' com 63 linhas.
